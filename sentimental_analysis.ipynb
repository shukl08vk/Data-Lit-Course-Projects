# %% [markdown]
# <a href="https://colab.research.google.com/github/shukl08vk/Data-Lit-Course-Projects/blob/projects/sentimental_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 6.4MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = 'wD0C4s8Yn3wJ39ja7kv4kN0vQ'
consumer_secret = '4jIKUbcE4yKwJBRDY7kItTk12B6WsqNfU4kXCB9E31L8DPRngn'
access_token = '2926765286-851CCOXbiMaxo4pkNej7CrvHrXB8HwfIBGjbjrn'
access_token_secret = 'BABjOwq0K6nPvsqIvW7rVmiPMSJ3SKKlD5TqDY09yWpze'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Deep Learning', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @odsc: Expanding the application of deep le...
# 1  RT @al_bpc: The Hootenanny has officially begu...
# 2  The Hootenanny has officially begun and the in...
# 3  Blockchain to Aid Artificial Intelligence for ...
# 4  Ovarian Serous Cystadenocarcinoma Deep learnin...
# 5  @Joe_Sorci I don't disagree that the report sy...
# 6  RT @analyticbridge: Introduction to Deep Learn...
# 7  RT @DD_Wen_: Deep Learning in Python: Learn th...
# 8  What is Keras? The deep neural network API exp...
# 9  @drugrift @cxcassandraa Always put your mental...
# 2019-01-28 16:34:15

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @odsc: Expanding the application of deep le...
# 1   RT @al_bpc: The Hootenanny has officially begu...
# 2   The Hootenanny has officially begun and the in...
# 3   Blockchain to Aid Artificial Intelligence for ...
# 4   Ovarian Serous Cystadenocarcinoma Deep learnin...
# 5   @Joe_Sorci I don't disagree that the report sy...
# 6   RT @analyticbridge: Introduction to Deep Learn...
# 7   RT @DD_Wen_: Deep Learning in Python: Learn th...
# 8   What is Keras? The deep neural network API exp...
# 9   @drugrift @cxcassandraa Always put your mental...
# 10  RT @hiconcep: This telegram chatbot can notify...
# 11  “Enter the RobotriX, an extremely photorealist...
# 12  RT @StrokeAHA_ASA: Deep Learning Natural Langu...
# 13  “Predict” is Market Insight’s Simulation Model...
# 14  Deep learning networks can be thousands of lay...
# 15  RT @MarshaCollier: Analysis: “The Era of Deep ...
# ...
